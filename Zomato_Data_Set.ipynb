# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('zomato.csv',encoding='latin')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df['Cuisines'].mode()
# Out:
# 0    North Indian
# dtype: object

# %%
df['Cuisines'][df['Cuisines'].isna()]='North Indian'
# Out:
# C:\Users\Haidar\AppData\Local\Temp/ipykernel_2416/2042130122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cuisines'][df['Cuisines'].isna()]='North Indian'

# %%
df['Cuisines'].isna().sum()
# Out:
# 0

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.groupby(['Restaurant Name','Votes'],sort=False).size().reset_index().head(5)
# Out:
#           Restaurant Name  Votes  0
# 0        Le Petit Souffle    314  1
# 1        Izakaya Kikufuji    591  1
# 2  Heat - Edsa Shangri-La    270  1
# 3                    Ooma    365  1
# 4             Sambo Kojin    229  1

# %%
def res_top(x,y):
    df.groupby([x,y],sort=False).size().reset_index().head(5)
    return(df.groupby([x,y],sort=False).size().reset_index().head(5))

# %%
res_top(df['Restaurant Name'],df['Votes'])
# Out:
#           Restaurant Name  Votes  0
# 0        Le Petit Souffle    314  1
# 1        Izakaya Kikufuji    591  1
# 2  Heat - Edsa Shangri-La    270  1
# 3                    Ooma    365  1
# 4             Sambo Kojin    229  1

# %%
top_res(df['Restaurant Name'],df['Votes'])

# %%
df.groupby(['Restaurant Name','Aggregate rating'],sort=True).size().reset_index().head(5)
# Out:
#   Restaurant Name  Aggregate rating  0
# 0    Let's Burrrp               0.0  1
# 1             #45               3.6  1
# 2    #Dilliwaala6               3.7  1
# 3    #InstaFreeze               0.0  1
# 4     #OFF Campus               3.7  1

# %%
df.groupby(['Restaurant Name','Votes']).size().reset_index().tail()
# Out:
#            Restaurant Name  Votes  0
# 9325    t Lounge by Dilmah     34  1
# 9326                tashas    374  1
# 9327              wagamama    131  1
# 9328  {Niche} - Cafe & Bar    492  1
# 9329   íukuraÛôa SofrasÛ±    296  1

# %%
df.Votes.sort_values(ascending=False)
# Out:
# 728     10934
# 735      9667
# 3994     7931
# 2412     7574
# 739      6907
#         ...
# 1016        0
# 1015        0
# 7836        0
# 7835        0
# 4524        0
# Name: Votes, Length: 9551, dtype: int64

# %%
df.Votes.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        314
# 1        591
# 2        270
# 3        365
# 4        229
#         ...
# 9546     788
# 9547    1034
# 9548     661
# 9549     901
# 9550     591
# Name: Votes, Length: 9551, dtype: int64>

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_num=df.select_dtypes(include='number')

# %%
df_cat=df.select_dtypes(exclude='number')

# %%
df.shape
# Out:
# (9551, 21)

# %%
a=5
b=4
c=1

for i in df_num:
    plt.subplot(a,b,c)
    sns.scatterplot()

# %%
df.groupby(['Restaurant Name','Aggregate rating'],axis=0,sort=False).size().reset_index()
# Out:
#                Restaurant Name  Aggregate rating  0
# 0             Le Petit Souffle               4.8  1
# 1             Izakaya Kikufuji               4.5  1
# 2       Heat - Edsa Shangri-La               4.4  1
# 3                         Ooma               4.9  1
# 4                  Sambo Kojin               4.8  1
# ...                        ...               ... ..
# 8708              NamlÛ± Gurme               4.1  1
# 8709             Ceviz AÛôacÛ±               4.2  1
# 8710                     Huqqa               3.7  1
# 8711              Aôôk Kahve               4.0  1
# 8712  Walter's Coffee Roastery               4.0  1
#
# [8713 rows x 3 columns]

# %%
df.sort_values(by=["Country Code","Aggregate rating"],ascending=False).groupby(["Country Code"])["Restaurant Name","Country Code","Aggregate rating"].head(5)
# Out:
# C:\Users\Haidar\AppData\Local\Temp/ipykernel_2416/2035360037.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.sort_values(by=["Country Code","Aggregate rating"],ascending=False).groupby(["Country Code"])["Restaurant Name","Country Code","Aggregate rating"].head(5)
#                Restaurant Name  Country Code  Aggregate rating
# 124         Rae's Coastal Cafe           216               4.9
# 175    Shorts Burger and Shine           216               4.9
# 213               Oakwood Cafe           216               4.9
# 235        Tantra Asian Bistro           216               4.9
# 250                   The Cafe           216               4.9
# ..                         ...           ...               ...
# 637            Sheroes Hangout             1               4.9
# 748      Sagar Gaire Fast Food             1               4.9
# ...

# %%
df.groupby('Country Code').size().reset_index().rename(columns={0:'Clusters'})
# Out:
#     Country Code  Clusters
# 0              1      8652
# 1             14        24
# 2             30        60
# 3             37         4
# 4             94        21
# 5            148        40
# 6            162        22
# 7            166        20
# 8            184        20
# 9            189        60
# 10           191        20
# 11           208        34
# 12           214        60
# 13           215        80
# 14           216       434

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")
Latitude = "28.4331150"
Longitude = "77.1037910"
location = geolocator.reverse(Latitude+","+Longitude)
print(location)
# Out:
# Sector 53, Gurgaon, Gurugram, Haryana, 122011, India
